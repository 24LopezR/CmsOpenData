# %% [markdown]
# ## Part 0: Load the dataset from CMSOpenData
#
# In this exercise we are going to use a dataset from the CMS Open Data portal. It is a DoubleMuon primary dataset in NANOAOD format from RunG of 2016. Run period from run number 278820 to 280385 [1]. It contains muon data from events from CMS collisions with at least 2 muons.
#
# NANOAOD datasets are in the ROOT tree format. This is a flat data structure, where we have for each collision (event) a list of muon particles that were reconstructed from the recorded detector signals. For each particle, we have a list of measured variables. Each of this variables is a "brnch" of the ROOT tree.
#
# [1] https://opendata.cern.ch/record/30522

# %%
cd ~/work/CmsOpenData/RDFAnalyzer
# Out:
# [Errno 2] No such file or directory: '/home/lopezr/work/CmsOpenData/RDFAnalyzer'
# /home/lopezr/Documents/work/teaching/CmsOpenData/RDFAnalyzer

# %%
# Import ROOT (ROOT is a analysis package used to handle 
# the tree files, but also histograms, etc.)
import ROOT as R

# Get the root file that contains the histograms for all muons: histos.root.
Hfile=R.TFile.Open("../data_skimmed/Run2016G_DoubleMuon_NANOAOD_UL2016_MiniAODv2_NanoAODv9-v2_2430000_05DD095C-F6C3-9A4F-9FB3-348A5A6403D5_skimmed.root", 
                 "READ")
# List the histograms stored in the file
Hfile.ls()

Hfile["Events"].Print()
# Out:
# TFile**		../data_skimmed/Run2016G_DoubleMuon_NANOAOD_UL2016_MiniAODv2_NanoAODv9-v2_2430000_05DD095C-F6C3-9A4F-9FB3-348A5A6403D5_skimmed.root
#  TFile*		../data_skimmed/Run2016G_DoubleMuon_NANOAOD_UL2016_MiniAODv2_NanoAODv9-v2_2430000_05DD095C-F6C3-9A4F-9FB3-348A5A6403D5_skimmed.root
#   KEY: TTree	Events;1	Events
# ******************************************************************************
# *Tree    :Events    : Events                                                 *
# *Entries :  2315223 : Total =      1296502941 bytes  File  Size =  562592185 *
# *        :          : Tree compression factor =   2.30                       *
# ******************************************************************************
# *Br    0 :run       : run/i                                                  *
# *Entries :  2315223 : Total  Size=    9284741 bytes  File Size  =      73725 *
# *Baskets :      256 : Basket Size=      36352 bytes  Compression= 125.86     *
# *............................................................................*
# *Br    1 :luminosityBlock : luminosityBlock/i                                *
# *Entries :  2315223 : Total  Size=    9287861 bytes  File Size  =      87523 *
# *Baskets :      256 : Basket Size=      36352 bytes  Compression= 106.06     *
# *............................................................................*
# *Br    2 :event     : event/l                                                *
# *Entries :  2315223 : Total  Size=   18546443 bytes  File Size  =    9133902 *
# *Baskets :      259 : Basket Size=      71680 bytes  Compression=   2.03     *
# *............................................................................*
# *Br    3 :nMuon     :                                                        *
# *         | UInt_t slimmedMuons after basic selection (pt > 15 || (pt > 3 && (passed('CutBasedIdLoose') || passed('SoftCutBasedId') || passed('SoftMvaId') || passed('CutBasedIdGlobalHighPt') || passed('CutBasedIdTrkHighPt'))))*
# *Entries :  2315223 : Total  Size=    9285461 bytes  File Size  =    1344625 *
# *Baskets :      256 : Basket Size=      36352 bytes  Compression=   6.90     *
# *............................................................................*
# *Br    4 :Muon_dxy  : Float_t dxy (with sign) wrt first PV, in cm            *
# *Entries :  2315223 : Total  Size=   28861665 bytes  File Size  =   17193066 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   1.68     *
# *............................................................................*
# *Br    5 :Muon_dxyErr : Float_t dxy uncertainty, in cm                       *
# *Entries :  2315223 : Total  Size=   28862642 bytes  File Size  =   12295168 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   2.35     *
# *............................................................................*
# *Br    6 :Muon_dxybs : Float_t dxy (with sign) wrt the beam spot, in cm      *
# *Entries :  2315223 : Total  Size=   28862330 bytes  File Size  =   17107309 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   1.69     *
# *............................................................................*
# *Br    7 :Muon_dz   : Float_t dz (with sign) wrt first PV, in cm             *
# *Entries :  2315223 : Total  Size=   28861334 bytes  File Size  =   17232982 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   1.67     *
# *............................................................................*
# *Br    8 :Muon_dzErr : Float_t dz uncertainty, in cm                         *
# *Entries :  2315223 : Total  Size=   28862311 bytes  File Size  =   12585062 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   2.29     *
# *............................................................................*
# *Br    9 :Muon_eta  : Float_t eta                                            *
# *Entries :  2315223 : Total  Size=   28861633 bytes  File Size  =   17132677 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   1.68     *
# *............................................................................*
# *Br   10 :Muon_ip3d : Float_t 3D impact parameter wrt first PV, in cm        *
# *Entries :  2315223 : Total  Size=   28861999 bytes  File Size  =   16635135 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   1.73     *
# *............................................................................*
# *Br   11 :Muon_jetPtRelv2 :                                                  *
# *         | Float_t Relative momentum of the lepton with respect to the closest jet after subtracting the lepton*
# *Entries :  2315223 : Total  Size=   28864032 bytes  File Size  =   14219737 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   2.03     *
# *............................................................................*
# *Br   12 :Muon_jetRelIso :                                                   *
# *         | Float_t Relative isolation in matched jet (1/ptRatio-1, pfRelIso04_all if no matched jet)*
# *Entries :  2315223 : Total  Size=   28863691 bytes  File Size  =   14964419 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   1.93     *
# *............................................................................*
# *Br   13 :Muon_mass : Float_t mass                                           *
# *Entries :  2315223 : Total  Size=   28861964 bytes  File Size  =    5796415 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   4.98     *
# *............................................................................*
# *Br   14 :Muon_miniPFRelIso_all :                                            *
# *         | Float_t mini PF relative isolation, total (with scaled rho*EA PU corrections)*
# *Entries :  2315223 : Total  Size=   28865989 bytes  File Size  =   19198642 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   1.50     *
# *............................................................................*
# *Br   15 :Muon_miniPFRelIso_chg :                                            *
# *         | Float_t mini PF relative isolation, charged component            *
# *Entries :  2315223 : Total  Size=   28865965 bytes  File Size  =   16501934 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   1.75     *
# *............................................................................*
# *Br   16 :Muon_pfRelIso03_all :                                              *
# *         | Float_t PF relative isolation dR=0.3, total (deltaBeta corrections)*
# *Entries :  2315223 : Total  Size=   28865319 bytes  File Size  =   19749398 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   1.46     *
# *............................................................................*
# *Br   17 :Muon_pfRelIso03_chg :                                              *
# *         | Float_t PF relative isolation dR=0.3, charged component          *
# *Entries :  2315223 : Total  Size=   28865307 bytes  File Size  =   18507581 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   1.56     *
# *............................................................................*
# *Br   18 :Muon_pfRelIso04_all :                                              *
# *         | Float_t PF relative isolation dR=0.4, total (deltaBeta corrections)*
# *Entries :  2315223 : Total  Size=   28865319 bytes  File Size  =   20627106 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   1.40     *
# *............................................................................*
# *Br   19 :Muon_phi  : Float_t phi                                            *
# *Entries :  2315223 : Total  Size=   28861633 bytes  File Size  =   17096130 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   1.69     *
# *............................................................................*
# *Br   20 :Muon_pt   : Float_t pt                                             *
# *Entries :  2315223 : Total  Size=   28861302 bytes  File Size  =   21506845 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   1.34     *
# *............................................................................*
# *Br   21 :Muon_ptErr : Float_t ptError of the muon track                     *
# *Entries :  2315223 : Total  Size=   28862315 bytes  File Size  =   13179028 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   2.19     *
# *............................................................................*
# *Br   22 :Muon_segmentComp : Float_t muon segment compatibility              *
# *Entries :  2315223 : Total  Size=   28864296 bytes  File Size  =   15779107 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   1.83     *
# *............................................................................*
# *Br   23 :Muon_sip3d : Float_t 3D impact parameter significance wrt first PV *
# *Entries :  2315223 : Total  Size=   28862335 bytes  File Size  =   16315746 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   1.77     *
# *............................................................................*
# *Br   24 :Muon_softMva : Float_t soft MVA ID score                           *
# *Entries :  2315223 : Total  Size=   28862967 bytes  File Size  =   10758583 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   2.68     *
# *............................................................................*
# *Br   25 :Muon_tkRelIso :                                                    *
# *         | Float_t Tracker-based relative isolation dR=0.3 for highPt, trkIso/tunePpt*
# *Entries :  2315223 : Total  Size=   28863346 bytes  File Size  =   12340967 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   2.34     *
# *............................................................................*
# *Br   26 :Muon_tunepRelPt : Float_t TuneP relative pt, tunePpt/pt            *
# *Entries :  2315223 : Total  Size=   28863969 bytes  File Size  =    5550602 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   5.20     *
# *............................................................................*
# *Br   27 :Muon_mvaLowPt : Float_t Low pt muon ID score                       *
# *Entries :  2315223 : Total  Size=   28863300 bytes  File Size  =   15791681 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   1.83     *
# *............................................................................*
# *Br   28 :Muon_mvaTTH : Float_t TTH MVA lepton ID score                      *
# *Entries :  2315223 : Total  Size=   28862643 bytes  File Size  =   15774456 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   1.83     *
# *............................................................................*
# *Br   29 :Muon_charge : Int_t electric charge                                *
# *Entries :  2315223 : Total  Size=   28862628 bytes  File Size  =    6589823 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   4.38     *
# *............................................................................*
# *Br   30 :Muon_jetIdx : Int_t index of the associated jet (-1 if none)       *
# *Entries :  2315223 : Total  Size=   28862653 bytes  File Size  =    8101986 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   3.56     *
# *............................................................................*
# *Br   31 :Muon_nStations :                                                   *
# *         | Int_t number of matched stations with default arbitration (segment & track)*
# *Entries :  2315223 : Total  Size=   28863672 bytes  File Size  =    7554208 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   3.82     *
# *............................................................................*
# *Br   32 :Muon_nTrackerLayers : Int_t number of layers in the tracker        *
# *Entries :  2315223 : Total  Size=   28865284 bytes  File Size  =    8331079 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   3.46     *
# *............................................................................*
# *Br   33 :Muon_pdgId :                                                       *
# *         | Int_t PDG code assigned by the event reconstruction (not by MC truth)*
# *Entries :  2315223 : Total  Size=   28862346 bytes  File Size  =    6526837 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   4.42     *
# *............................................................................*
# *Br   34 :Muon_tightCharge :                                                 *
# *         | Int_t Tight charge criterion using pterr/pt of muonBestTrack (0: *
# *         | fail, 2:pass)                                                    *
# *Entries :  2315223 : Total  Size=   28864334 bytes  File Size  =    4141747 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   6.97     *
# *............................................................................*
# *Br   35 :Muon_fsrPhotonIdx : Int_t Index of the associated FSR photon       *
# *Entries :  2315223 : Total  Size=   28864627 bytes  File Size  =    4234900 *
# *Baskets :      327 : Basket Size=     116736 bytes  Compression=   6.81     *
# *............................................................................*
# *Br   36 :Muon_highPtId :                                                    *
# *         | UChar_t high-pT cut-based ID (1 = tracker high pT, 2 = global high pT, which includes tracker high pT)*
# *Entries :  2315223 : Total  Size=   14194249 bytes  File Size  =    5544162 *
# *Baskets :      376 : Basket Size=      62464 bytes  Compression=   2.56     *
# *............................................................................*
# *Br   37 :Muon_highPurity : Bool_t inner track is high purity                *
# *Entries :  2315223 : Total  Size=   14194939 bytes  File Size  =    4773178 *
# *Baskets :      376 : Basket Size=      62464 bytes  Compression=   2.97     *
# *............................................................................*
# *Br   38 :Muon_inTimeMuon : Bool_t inTimeMuon ID                             *
# *Entries :  2315223 : Total  Size=   14194926 bytes  File Size  =    4142912 *
# *Baskets :      376 : Basket Size=      62464 bytes  Compression=   3.42     *
# *............................................................................*
# *Br   39 :Muon_isGlobal : Bool_t muon is global muon                         *
# *Entries :  2315223 : Total  Size=   14194174 bytes  File Size  =    5130275 *
# *Baskets :      376 : Basket Size=      62464 bytes  Compression=   2.77     *
# *............................................................................*
# *Br   40 :Muon_isPFcand : Bool_t muon is PF candidate                        *
# *Entries :  2315223 : Total  Size=   14194175 bytes  File Size  =    5125612 *
# *Baskets :      376 : Basket Size=      62464 bytes  Compression=   2.77     *
# *............................................................................*
# *Br   41 :Muon_isStandalone : Bool_t muon is a standalone muon               *
# *Entries :  2315223 : Total  Size=   14195696 bytes  File Size  =    5044113 *
# *Baskets :      376 : Basket Size=      62464 bytes  Compression=   2.81     *
# *............................................................................*
# *Br   42 :Muon_isTracker : Bool_t muon is tracker muon                       *
# *Entries :  2315223 : Total  Size=   14194554 bytes  File Size  =    4940576 *
# *Baskets :      376 : Basket Size=      62464 bytes  Compression=   2.87     *
# *............................................................................*
# *Br   43 :Muon_jetNDauCharged :                                              *
# *         | UChar_t number of charged daughters of the closest jet           *
# *Entries :  2315223 : Total  Size=   14196475 bytes  File Size  =    6724322 *
# *Baskets :      376 : Basket Size=      62464 bytes  Compression=   2.11     *
# *............................................................................*
# *Br   44 :Muon_looseId : Bool_t muon is loose muon                           *
# *Entries :  2315223 : Total  Size=   14193794 bytes  File Size  =    5128273 *
# *Baskets :      376 : Basket Size=      62464 bytes  Compression=   2.77     *
# *............................................................................*
# *Br   45 :Muon_mediumId : Bool_t cut-based ID, medium WP                     *
# *Entries :  2315223 : Total  Size=   14194178 bytes  File Size  =    5302570 *
# *Baskets :      376 : Basket Size=      62464 bytes  Compression=   2.68     *
# *............................................................................*
# *Br   46 :Muon_mediumPromptId : Bool_t cut-based ID, medium prompt WP        *
# *Entries :  2315223 : Total  Size=   14196459 bytes  File Size  =    5566636 *
# *Baskets :      376 : Basket Size=      62464 bytes  Compression=   2.55     *
# *............................................................................*
# *Br   47 :Muon_miniIsoId :                                                   *
# *         | UChar_t MiniIso ID from miniAOD selector (1=MiniIsoLoose, 2=MiniIsoMedium, 3=MiniIsoTight, 4=MiniIsoVeryTight)*
# *Entries :  2315223 : Total  Size=   14194636 bytes  File Size  =    6098179 *
# *Baskets :      376 : Basket Size=      62464 bytes  Compression=   2.33     *
# *............................................................................*
# *Br   48 :Muon_multiIsoId :                                                  *
# *         | UChar_t MultiIsoId from miniAOD selector (1=MultiIsoLoose, 2=MultiIsoMedium)*
# *Entries :  2315223 : Total  Size=   14194981 bytes  File Size  =    5337491 *
# *Baskets :      376 : Basket Size=      62464 bytes  Compression=   2.66     *
# *............................................................................*
# *Br   49 :Muon_mvaId :                                                       *
# *         | UChar_t Mva ID from miniAOD selector (1=MvaLoose, 2=MvaMedium, 3=MvaTight, 4=MvaVTight, 5=MvaVVTight)*
# *Entries :  2315223 : Total  Size=   14193111 bytes  File Size  =    5461988 *
# *Baskets :      376 : Basket Size=      62464 bytes  Compression=   2.60     *
# *............................................................................*
# *Br   50 :Muon_mvaLowPtId :                                                  *
# *         | UChar_t Low Pt Mva ID from miniAOD selector (1=LowPtMvaLoose, 2=LowPtMvaMedium)*
# *Entries :  2315223 : Total  Size=   14194984 bytes  File Size  =    3917102 *
# *Baskets :      376 : Basket Size=      62464 bytes  Compression=   3.62     *
# *............................................................................*
# *Br   51 :Muon_pfIsoId :                                                     *
# *         | UChar_t PFIso ID from miniAOD selector (1=PFIsoVeryLoose, 2=PFIsoLoose, 3=PFIsoMedium, 4=PFIsoTight, 5=PFIsoVeryTight, 6=PFIsoVeryVeryTight)*
# *Entries :  2315223 : Total  Size=   14193908 bytes  File Size  =    6166001 *
# *Baskets :      376 : Basket Size=      62464 bytes  Compression=   2.30     *
# *............................................................................*
# *Br   52 :Muon_puppiIsoId :                                                  *
# *         | UChar_t PuppiIsoId from miniAOD selector (1=Loose, 2=Medium, 3=Tight)*
# *Entries :  2315223 : Total  Size=   14194974 bytes  File Size  =    5764971 *
# *Baskets :      376 : Basket Size=      62464 bytes  Compression=   2.46     *
# *............................................................................*
# *Br   53 :Muon_softId : Bool_t soft cut-based ID                             *
# *Entries :  2315223 : Total  Size=   14193414 bytes  File Size  =    5152283 *
# *Baskets :      376 : Basket Size=      62464 bytes  Compression=   2.75     *
# *............................................................................*
# *Br   54 :Muon_softMvaId : Bool_t soft MVA ID                                *
# *Entries :  2315223 : Total  Size=   14194545 bytes  File Size  =    5544948 *
# *Baskets :      376 : Basket Size=      62464 bytes  Compression=   2.56     *
# *............................................................................*
# *Br   55 :Muon_tightId : Bool_t cut-based ID, tight WP                       *
# *Entries :  2315223 : Total  Size=   14193798 bytes  File Size  =    5480858 *
# *Baskets :      376 : Basket Size=      62464 bytes  Compression=   2.59     *
# *............................................................................*
# *Br   56 :Muon_tkIsoId : UChar_t TkIso ID (1=TkIsoLoose, 2=TkIsoTight)       *
# *Entries :  2315223 : Total  Size=   14193813 bytes  File Size  =    5647382 *
# *Baskets :      376 : Basket Size=      62464 bytes  Compression=   2.51     *
# *............................................................................*
# *Br   57 :Muon_triggerIdLoose : Bool_t TriggerIdLoose ID                     *
# *Entries :  2315223 : Total  Size=   14196446 bytes  File Size  =    5165783 *
# *Baskets :      376 : Basket Size=      62464 bytes  Compression=   2.75     *
# *............................................................................*
# *Br   58 :Muon_cleanmask :                                                   *
# *         | UChar_t simple cleaning mask with priority to leptons            *
# *Entries :  2315223 : Total  Size=   14194579 bytes  File Size  =    5283613 *
# *Baskets :      376 : Basket Size=      62464 bytes  Compression=   2.69     *
# *............................................................................*
